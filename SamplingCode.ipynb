# %%
import pandas as pd
df = pd.read_csv('human_cognitive_performance.csv')

sample_df = df.sample(n=800, random_state=42)  # random_state for reproducibility

sample_df.to_csv('sampled_data.csv', index=False)
